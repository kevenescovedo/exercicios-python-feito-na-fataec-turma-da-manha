# %% [markdown]
# #**EXERCÍCIOS - V E T O R  - EXTRA**

# %% [markdown]
# ### 1. Faça um programa que:
#
# * preencha um vetor com seis elementos numéricos inteiros.
#
# **Calcule e mostre:**
#
# * todos os números pares;
# * a quantidade de números pares;
# * todos os números ímpares;
# * a quantidade de números ímpares

# %%
# Digite seu código aqui.

# %% [markdown]
# ### 2. Faça um programa que:
#
# * Preencha um vetor com sete números inteiros,
#
# **Calcule (%) e mostre os números:**
#
# * Múltiplos de 2;
# * Múltiplos de 3;
# * Múltiplos de 2 e de 3.

# %%
# Digite seu código aqui.

# %% [markdown]
# ### 3. Faça um programa que:
#
# * Preencha um vetor com quinze elementos inteiros
# * Verifique a existência de elementos iguais a 30, mostrando as posições em que apareceram.

# %%
# Digite seu código aqui.

# %% [markdown]
# ### 4.Faça um programa que:
#
# * Preencha um vetor com dez números reais (float)
#
# **Calcule e mostre:**
#
# * A quantidade de números negativos
# * A soma dos números positivos desse vetor. Não use a função sum().

# %%
# Digite seu código aqui.

# %% [markdown]
# ### 5. Faça um programa que:
#
# * Receba dez números inteiros e armazene-os em um vetor
# * Armazene os numeros em dois vetores, um com números pares e o outro com os ímpares

# %%
# Digite seu código aqui.

# %% [markdown]
# ### 6. Faça um programa que:
#
# * Receba cinco números e mostre a saída a seguir:
# * Imprima a seguinte saída: n1 + n2 + n3 + n4 + n5 = soma_dos_numeros(valor)

# %%
# Digite seu código aqui.

# %% [markdown]
# ### 7. Faça um programa que:
#
# * Preencha dois vetores com de dez numeros cada
# * Preecha um terceira vetor com os números dos dois vetores anteriores ordenados em ordem crescente

# %%
# Digite seu código aqui.

# %% [markdown]
# ### 8. Faça um programa que:
#
# * Preencha um vetor com quinze números,
#
# **Determine e mostre:**
#
# * O maior número e a posição por ele ocupada no vetor;
# * O menor número e a posição por ele ocupada no vetor.

# %%
# Digite seu código aqui.

# %% [markdown]
# ### 9. Faça um programa que:
#
# * Preencha dois vetores com 10 números cada
# * Faça a multiplicação dos números na mesma posição V1[0] * V2[0] ...
# * O resultado deverá ser inserido no terceiro vetor

# %%
# Digite seu código aqui.

# %% [markdown]
# ### 10. Faça um programa que:
#
# * Leia um vetor com 10 números inteiros
# * Exiba apenas os números positivos.

# %%
# Digite seu código aqui.

# %% [markdown]
# ### 11. Faça um programa que:
#
# * Insira dez números inteiros em um vetor
# * Crie um segundo vetor, substituindo os números multiplos de 3 por " * "
# * Exiba os dois vetores

# %%
# Digite seu código aqui.

# %% [markdown]
# ### 12. Faça um programa que:
# * Adicione 10 números inteiros em um vetor A.
# * Remova todos os números menores que 0 do vetor A e os adicione no vetor B
# * Exiba os vetores A e B

# %%
# Digite seu código aqui.

# %% [markdown]
# ### 13. Faça um programa que:
#
# * Leia dois vetores (A e B) com cinco posições para números inteiros.
# * O programa deve, então, subtrair o primeiro elemento de A do último de B, armazenando no vetor C, subtrair o segundo elemento de A do penúltimo de B, armazenando no vetor C e assim por diante.
# * Ao final, mostre o resultado de todas as subtrações realizadas que estão no vetor C.

# %%
# Digite seu código aqui.

# %% [markdown]
# ### 14. Faça um programa que:
# * Leia um vetor com quinze posições para números inteiros.
# * Crie, a seguir, um vetor resultante que contenha todos os números primos do vetor digitado.
# * Escreva o vetor resultante.

# %%
# Digite seu código aqui.

# %% [markdown]
# ### 15. Faça um programa que:
# * Leia um vetor com quinze posições para números inteiros.
# * Depois da leitura, divida todos os seus elementos pelo maior valor do vetor. Não use a função max().
# * Mostre o vetor após os cálculos.

# %%
# Digite seu código aqui.
